# %%
# !git clone https://github.com/DepthAnything/Depth-Anything-V2.git
# %cd Depth-Anything-V2
# Out:
# Cloning into 'Depth-Anything-V2'...
# remote: Enumerating objects: 146, done.
# remote: Total 146 (delta 0), reused 0 (delta 0), pack-reused 146 (from 1)
# Receiving objects: 100% (146/146), 45.18 MiB | 23.55 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/Depth-Anything-V2

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.5/101.5 kB 4.7 MB/s eta 0:00:00
# ...

# %%
# !mkdir -p checkpoints

# !wget https://huggingface.co/depth-anything/Depth-Anything-V2-Small/resolve/main/depth_anything_v2_vits.pth -O checkpoints/depth_anything_v2_vits.pth
# Out:
# --2026-06-27 09:57:48--  https://huggingface.co/depth-anything/Depth-Anything-V2-Small/resolve/main/depth_anything_v2_vits.pth
# Resolving huggingface.co (huggingface.co)... 18.164.174.23, 18.164.174.55, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.aws.cdn.hf.co/xet-bridge-us/666b17aaed1ed0f9bf42823e/01950a0198f6ece4acfd924dbc91f9f6bed4b614a222d64ad3c516ba39447464?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27depth_anything_v2_vits.pth%3B+filename%3D%22depth_anything_v2_vits.pth%22%3B&user_id=public&X-Xet-Cas-Uid=public&Expires=1782557868&Policy=..._&Signature=MEQCIGxCZCb1S7pVHKJPRqdLENSnv13daOkb-ec2apuJ7EQeAiBXPLDnj93aQDMmErrYQf1CCLFR2jVP56TZzHrmNCZGdA__&Key-Pair-Id=01KAYHXK2CBJSW0YZTMNXK9W1M [following]
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-26055558-708d-475c-a0d8-c869d1d07822" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26055558-708d-475c-a0d8-c869d1d07822">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python run.py \
    --img-path funny-cat-26.jpg \
    --encoder vits \
    --outdir outputs
# Out:
# xFormers not available
# xFormers not available
# Progress 1/1: funny-cat-26.jpg

# %%
# !find outputs -type f
# Out:
# outputs/funny-cat-26.png

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("outputs/funny-cat-26.png")

plt.figure(figsize=(8,8))
plt.imshow(img)
plt.axis("off")
plt.show()
